# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl

import warnings
warnings.filterwarnings(action="ignore")

# %%
fontpath = '/usr/share/fonts/NanumGothic.ttf'

fname = mpl.font_manager.FontProperties(fname=fontpath).get_name()

# %%
mpl.rcParams['font.family'] = 'NanumGothic'
mpl.rcParams['font.size'] = 12
mpl.rcParams['axes.unicode_minus'] = False

# %%
pd.set_option('display.max_columns',100)

# %%
sf = pd.read_csv('csv/seoul_food.csv')
sf.head() #  50개 컬럼이 다 안보인다. :: set_option설정
# Out:
#    Unnamed: 0  개방자치단체코드                    관리번호     인허가일자  인허가취소일자  영업상태코드  \
# 0           0   3010000  3010000-104-2020-00245  20201229      NaN       1
# 1           1   3070000  3070000-104-2020-00105  20200713      NaN       1
# 2           2   3230000  3230000-104-2020-00227  20200713      NaN       1
# 3           3   3050000  3050000-104-2020-00106  20200713      NaN       1
# 4           4   3080000  3080000-104-2020-00065  20200713      NaN       1
#
#    영업상태명  상세영업상태코드 상세영업상태명  폐업일자  휴업시작일자  휴업종료일자  재개업일자 전화번호   소재지면적  \
# 0  영업/정상         1      영업   NaN     NaN     NaN    NaN  NaN   10.00
# 1  영업/정상         1      영업   NaN     NaN     NaN    NaN  NaN    6.60
# 2  영업/정상         1      영업   NaN     NaN     NaN    NaN  NaN  329.89
# 3  영업/정상         1      영업   NaN     NaN     NaN    NaN  NaN   26.00
# 4  영업/정상         1      영업   NaN     NaN     NaN    NaN  NaN   32.00
#
#     소재지우편번호                        지번주소  \
# 0  100440.0  서울특별시 중구 황학동 2545 이마트 청계천점
# 1  136110.0   서울특별시 성북구 길음동 1280-6 대우상가
# 2  138827.0    서울특별시 송파구 방이동 44-3 현대토픽스
# 3  130850.0       서울특별시 동대문구 전농동 38-104
# 4  142870.0        서울특별시 강북구 수유동 413-25
#
#                                          도로명주소  도로명우편번호          사업장명  \
# 0        서울특별시 중구 청계천로 400 지하2층 (황학동 롯데캐슬베네치아)   4572.0    통불 이마트청계천점
# 1  서울특별시 성북구 길음로 103 대우상가 상가동 1층 105106호 (길음동)   2714.0    씨유 길음푸르지오점
# 2                   서울특별시 송파구 위례성대로 6 1층 (방이동)   5544.0          스타벅스
# 3                서울특별시 동대문구 전농로16길 54 1층 (전농동)   2508.0  Min's coffee
# 4                 서울특별시 강북구 삼양로87길 46 1층 (수유동)   1090.0          탑브릭스
#
#            최종수정일자 데이터갱신구분                데이터갱신일자   업태구분명        좌표정보(X)  \
# 0  20201229130352       I  2019-11-01 21:01:00.0  일반조리판매  201823.908977
# 1  20200713175725       I  2019-12-06 23:05:00.0     편의점  201517.385330
# 2  20200713162510       I  2019-12-06 23:05:00.0     커피숍  209929.574783
# 3  20200713161446       I  2019-12-06 23:05:00.0     커피숍  205263.826419
# 4  20200713160435       I  2019-12-06 23:05:00.0  일반조리판매  201292.010942
#
#          좌표정보(Y) 위생업태명  남성종사자수  여성종사자수 영업장주변구분명 등급구분명 급수시설구분명  총인원  본사종업원수  \
# 0  452076.818664   NaN     NaN     NaN      NaN   NaN     NaN  NaN     NaN
# 1  456504.561867   NaN     NaN     NaN      NaN   NaN     NaN  NaN     NaN
# 2  446085.121305   NaN     NaN     NaN      NaN   NaN     NaN  NaN     NaN
# 3  452869.992526   NaN     NaN     NaN      NaN   NaN     NaN  NaN     NaN
# 4  459312.320008   NaN     NaN     NaN      NaN   NaN     NaN  NaN     NaN
#
#    공장사무직종업원수  공장판매직종업원수  공장생산직종업원수 건물소유구분명  보증액  월세액 다중이용업소여부  시설총규모 전통업소지정번호  \
# 0        NaN        NaN        NaN     NaN  NaN  NaN      NaN    NaN      NaN
# 1        NaN        NaN        NaN     NaN  NaN  NaN      NaN    NaN      NaN
# 2        NaN        NaN        NaN     NaN  NaN  NaN      NaN    NaN      NaN
# 3        NaN        NaN        NaN     NaN  NaN  NaN      NaN    NaN      NaN
# 4        NaN        NaN        NaN     NaN  NaN  NaN      NaN    NaN      NaN
#
#   전통업소주된음식  홈페이지   지역구  open  closed          경도         위도
# 0      NaN   NaN    중구  2020     NaN  127.021434  37.570978
# 1      NaN   NaN   성북구  2020     NaN  127.017973  37.610872
# 2      NaN   NaN   송파구  2020     NaN  127.113106  37.516942
# 3      NaN   NaN  동대문구  2020     NaN  127.060378  37.578112
# 4      NaN   NaN   강북구  2020     NaN  127.015425  37.636170

# %%
sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108372 entries, 0 to 108371
# Data columns (total 50 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  108372 non-null  int64
#  1   개방자치단체코드    108372 non-null  int64
#  2   관리번호        108372 non-null  object
#  3   인허가일자       108372 non-null  int64
#  4   인허가취소일자     0 non-null       float64
#  5   영업상태코드      108372 non-null  int64
#  6   영업상태명       108372 non-null  object
#  7   상세영업상태코드    108372 non-null  int64
#  8   상세영업상태명     108372 non-null  object
#  9   폐업일자        74441 non-null   float64
#  10  휴업시작일자      0 non-null       float64
#  11  휴업종료일자      0 non-null       float64
#  12  재개업일자       0 non-null       float64
#  13  전화번호        56882 non-null   object
#  14  소재지면적       100325 non-null  float64
#  15  소재지우편번호     108187 non-null  float64
#  16  지번주소        108189 non-null  object
#  17  도로명주소       66753 non-null   object
#  18  도로명우편번호     66077 non-null   float64
#  19  사업장명        108372 non-null  object
#  20  최종수정일자      108372 non-null  int64
#  21  데이터갱신구분     108372 non-null  object
#  22  데이터갱신일자     108372 non-null  object
#  23  업태구분명       108372 non-null  object
#  24  좌표정보(X)     103801 non-null  float64
#  25  좌표정보(Y)     103801 non-null  float64
#  26  위생업태명       94669 non-null   object
#  27  남성종사자수      35804 non-null   float64
#  28  여성종사자수      36078 non-null   float64
#  29  영업장주변구분명    34249 non-null   object
#  30  등급구분명       32993 non-null   object
#  31  급수시설구분명     47591 non-null   object
#  32  총인원         0 non-null       float64
#  33  본사종업원수      101 non-null     float64
#  34  공장사무직종업원수   101 non-null     float64
#  35  공장판매직종업원수   101 non-null     float64
#  36  공장생산직종업원수   101 non-null     float64
#  37  건물소유구분명     4 non-null       object
#  38  보증액         101 non-null     float64
#  39  월세액         101 non-null     float64
#  40  다중이용업소여부    94669 non-null   object
#  41  시설총규모       94669 non-null   float64
#  42  전통업소지정번호    68 non-null      object
#  43  전통업소주된음식    5 non-null       object
#  44  홈페이지        0 non-null       float64
#  45  지역구         108372 non-null  object
#  46  open        108372 non-null  int64
#  47  closed      74441 non-null   float64
#  48  경도          108372 non-null  float64
#  49  위도          108372 non-null  float64
# dtypes: float64(24), int64(7), object(19)
# memory usage: 41.3+ MB

# %%
# 분석에 용이한 컬럼들만 추출해 새로운 데이터프레임 생성
# sf.columns
sf1 = sf.iloc[:, [19, 45, 23, 46, 47, 40, 16, 48, 49, 24, 25]]

sf1.head(10)
# Out:
#             사업장명   지역구   업태구분명  open  closed 다중이용업소여부  \
# 0     통불 이마트청계천점    중구  일반조리판매  2020     NaN      NaN
# 1     씨유 길음푸르지오점   성북구     편의점  2020     NaN      NaN
# 2           스타벅스   송파구     커피숍  2020     NaN      NaN
# 3   Min's coffee  동대문구     커피숍  2020     NaN      NaN
# 4           탑브릭스   강북구  일반조리판매  2020     NaN      NaN
# 5          티오르카페   강서구     커피숍  2020     NaN      NaN
# 6  씨유 중랑센트럴아이파크점   중랑구     편의점  2020     NaN      NaN
# 7       씨유 현대행운점   송파구     편의점  2020     NaN      NaN
# 8       애견용품할인매장   관악구     커피숍  2020     NaN      NaN
# 9          오버스토리   성북구     커피숍  2020     NaN      NaN
#
#                                 지번주소          경도         위도
# 0         서울특별시 중구 황학동 2545 이마트 청계천점  127.021434  37.570978
# 1          서울특별시 성북구 길음동 1280-6 대우상가  127.017973  37.610872
# 2           서울특별시 송파구 방이동 44-3 현대토픽스  127.113106  37.516942
# 3              서울특별시 동대문구 전농동 38-104  127.060378  37.578112
# 4               서울특별시 강북구 수유동 413-25  127.015425  37.636170
# 5  서울특별시 강서구 마곡동 773 힐스테이트에코마곡역 302호  127.082705  37.583486
# 6               서울특별시 중랑구 면목동 156-23  127.127751  37.507124
# 7                 서울특별시 송파구 오금동 42-5  126.918644  37.474785
# 8               서울특별시 관악구 신림동 608-30  126.999678  37.598753
# 9                 서울특별시 성북구 성북동 8-28  126.962546  37.524286

# %%
# 음식점 종류 알아보기
사업장 = sf1.사업장명.value_counts()

사업장30 = 사업장.sort_values(ascending=False).head(30)

사업장30
# Out:
# 이디야         735
# 스타벅스        643
# 롯데리아        443
# 던킨도너츠       331
# 커피빈         316
# 투썸플레이스      311
# 베스킨라빈스      283
# 탐앤탐스        222
# 엔제리너스       208
# 요거프레소       204
# 버거킹         201
# 피자스쿨        193
# 카페베네        188
# 맥도날드        175
# 할리스커피       166
# 빽다방         140
# 파스쿠찌        140
# 이삭토스트       107
# 도미노피자       102
# 약속           98
# 크라운베이커리      95
# KFC          80
# 맘스터치         77
# 약속다방         75
# 독일제과         71
# 피자나라치킨공주     69
# 마이빈          69
# 석봉토스트        69
# 초원           67
# 신라명과         66
# Name: 사업장명, dtype: int64

# %%
# 사업장30.plot(kind='bar', figsize=(12,6), title='사업장 현황', ylabel='점포수', color=plt.cm.Paired(np.arange(30)))
# 사업장30.plot(kind='bar', figsize=(12,6), title='사업장 현황', ylabel='점포수', color=plt.cm.tab20(np.arange(30)))
사업장30.plot(kind='bar', figsize=(12,6), title='사업장 현황', ylabel='점포수', color=plt.cm.prism(np.arange(30)))
# Out:
# <AxesSubplot:title={'center':'사업장 현황'}, ylabel='점포수'>

# %%
ax = 사업장30[:20].plot(kind='bar', figsize=(12,6), title='사업장 현황', ylabel='점포수', color=plt.cm.tab20(np.arange(20)))

# ax.annotate( 표시할값, x좌표, y좌표, 옵션)
for p in ax.patches:
    ax.annotate(p.get_height(), (p.get_x()-0.07, p.get_height()+5) )
    
ax
# Out:
# <AxesSubplot:title={'center':'사업장 현황'}, ylabel='점포수'>

# %%
# 서울의 카페는 모두 몇개나 될까
업태구분 = sf1.업태구분명.value_counts()
업태구분 = 업태구분.sort_values(ascending=False)
업태구분


ax = 업태구분[:15].plot(kind='bar', figsize=(12,6), color=plt.cm.tab20(np.arange(20)))
for p in ax.patches:
    ax.annotate('{:5,d}'.format(p.get_height()), (p.get_x()-0.03, p.get_height()+400) )    
ax
# Out:
# <AxesSubplot:>

# %%
# 다방의 갯수가 17,249개 - 다방의 종류는 무엇?
search = sf1.업태구분명 == '다방'
다방 = sf1[search]
# 다방.head()

다방.사업장명.value_counts().sort_values(ascending=False).head(20)
# Out:
# 약속      94
# 약속다방    73
# 커피타임    59
# 팡세      58
# 솔       57
# 초원      55
# 제일      54
# 정       52
# 태양      51
# 영       49
# 영다방     46
# 정다방     46
# 중앙다방    44
# 수정      44
# 한일      43
# 양지      42
# 궁전      41
# 귀빈      40
# 장미      39
# 중앙      39
# Name: 사업장명, dtype: int64

# %%
# 년도별 다방의 갯수는 
개업다방 = 다방.groupby(['open','사업장명'])['사업장명'].count()

개업다방 = 개업다방.sort_values(ascending=False)
개업다방[:20]
# Out:
# open  사업장명
# 1992  커피타임     22
# 1993  커피타임     18
# 1981  솔        15
# 1996  팡세       15
# 1993  뜨레모아     13
#       커피라인     13
# 1995  팡세       12
# 1984  약속       11
# 2002  스위트번스    11
# 1994  커피타임     11
# 1985  약속       10
# 1997  팡세       10
# 1994  사카       10
# 1988  약속다방      9
# 1994  팡세        9
# 1993  폴링        9
# 1983  정         9
# 1993  브레머       9
#       사카        9
# 1984  솔         8
# Name: 사업장명, dtype: int64

# %%
# 지금 현재 영업중인 매장을 대상으로 다시 추출 
스타벅스 = sf1[(sf1.사업장명 == '스타벅스') & (sf1.closed.isnull())]
스타벅스
# Out:
#         사업장명   지역구 업태구분명  open  closed 다중이용업소여부  \
# 2       스타벅스   송파구   커피숍  2020     NaN      NaN
# 106     스타벅스   마포구   커피숍  2020     NaN      NaN
# 163     스타벅스   동작구   커피숍  2018     NaN      NaN
# 183     스타벅스  서대문구   커피숍  2020     NaN      NaN
# 313     스타벅스   서초구   커피숍  2003     NaN      NaN
# ...      ...   ...   ...   ...     ...      ...
# 107608  스타벅스   도봉구   커피숍  2021     NaN      NaN
# 108083  스타벅스    중구   커피숍  2021     NaN      NaN
# 108110  스타벅스   관악구   커피숍  2017     NaN      NaN
# 108220  스타벅스   강남구   커피숍  2020     NaN      NaN
# 108228  스타벅스  동대문구   커피숍  2018     NaN      NaN
#
#                                                     지번주소          경도  \
# 2                               서울특별시 송파구 방이동 44-3 현대토픽스  127.113106
# 106                   서울특별시 강남구 삼성동 108-6번지 JBK TOWER 빌딩  126.899030
# 163                           서울특별시 서초구 서초동 1365-23번지 1층  127.018017
# 183                          서울특별시 강남구 역삼동 702-10 아남타워빌딩  127.138372
# 313                            서울특별시 서초구 서초동 1657-5번지 1층  127.018789
# ...                                                  ...         ...
# 107608                            서울특별시 영등포구 영등포동6가 1-14  126.874260
# 108083                             서울특별시 영등포구 양평동5가 64-1  126.993300
# 108110                         서울특별시 양천구 신정동 900-10 지상1층  127.003963
# 108220                                서울특별시 금천구 시흥동 1031  127.112243
# 108228  서울특별시 금천구 가산동 371-41 가산 에스케이 브이원 센터1층 106107108호  127.058819
#
#                위도
# 2       37.516942
# 106     37.569992
# 163     37.482788
# 183     37.544185
# 313     37.493376
# ...           ...
# 107608  37.523502
# 108083  37.480359
# 108110  37.486894
# 108220  37.501301
# 108228  37.512521
#
# [518 rows x 9 columns]

# %%
# 구별로 몇개의 이디야/스타벅스가 존재하는지 시각화
# 강남구에 있는 이디야/스타벅스의 위치를 지도에 시각화

# search = sf1.사업장명 == '스타벅스'

# star = sf1[search]

# star.head()


# 스타벅스 = star.groupby(['지역구','사업장명'])['사업장명'].count()

스타벅스.지역구.value_counts().sort_values(ascending=False)[:10]

# 스타벅스
# Out:
# 강남구     82
# 중구      52
# 영등포구    37
# 서초구     36
# 종로구     36
# 송파구     34
# 마포구     33
# 서대문구    18
# 강서구     16
# 양천구     16
# Name: 지역구, dtype: int64

# %%
# 강남구에 존재하는 이디야/ 스타벅스의 위치를 지도에 시각화
강남스벅 = 스타벅스[스타벅스.지번주소.str.contains('강남구')]
강남스벅.head()

latlng = []

# for i in range(len(강남스벅)):
#     latlng.append((강남스벅.iloc[i, 8], 강남스벅.iloc[i,7]))
    
# latlng[:5]

# %%
import googlemaps as ggmaps
import gmaps
from ipywidgets.embed import embed_minimal_html

# %%
mykey = 'AIzaSyBcaPtxKZ9HTVSMkf-kUVQwSH7UYgLPxZk'

# %%
# 구글맵 API 키 등록 
ggmaps = ggmaps.Client(key=mykey)

# %%
mysize = {'width':'1024px', 'height':'768px', 'border':'1px solid black', 'padding':'10px', 'margin':'10px' }
seoul = (37.566, 126.9784)

gmaps.configure(api_key=mykey)

fig = gmaps.figure(layout=mysize, center=seoul, zoom_level=12)

markers = gmaps.marker_layer(latlng)

fig.add_layer(markers)
embed_minimal_html('maps/starbucks.html', views=[fig])

# %%
# ax = 스타벅스[:].plot(kind='bar', figsize=(12,6), color=plt.cm.tab20(np.arange(20)))

# for p in ax.patches:
#     ax.annotate(p.get_height(), (p.get_x()-0.07, p.get_height()+1) )    
# ax
# Out:
# <AxesSubplot:>

# %%
search = (sf1.사업장명 == '스타벅스') & (sf1.지역구 == '강남구')

gn = sf1[search]

gn.head()

gn = gn.groupby(['지역구','사업장명','경도','위도'])['사업장명'].count()

gn
# Out:
# 지역구  사업장명  경도          위도
# 강남구  스타벅스  126.860359  37.525206    1
#            126.882839  37.501177    1
#            126.897302  37.466712    1
#            126.921492  37.472796    1
#            126.939497  37.564700    1
#                                    ..
#            127.146985  37.501263    1
#            127.148803  37.497480    1
#            127.149082  37.492693    1
#            127.151136  37.495646    1
#            127.151822  37.499253    1
# Name: 사업장명, Length: 105, dtype: int64

# %%
이디야 = sf1[(sf1.사업장명 == '이디야') & (sf.closed.isnull())]
이디야
# Out:
#        사업장명  지역구 업태구분명  open  closed 다중이용업소여부  \
# 42      이디야   중구   커피숍  2020     NaN      NaN
# 147     이디야  노원구   커피숍  2019     NaN      NaN
# 350     이디야  강동구   커피숍  2018     NaN      NaN
# 399     이디야  노원구   커피숍  2016     NaN      NaN
# 472     이디야  강남구   커피숍  2008     NaN      NaN
# ...     ...  ...   ...   ...     ...      ...
# 107004  이디야  강북구   커피숍  2020     NaN      NaN
# 107369  이디야  중랑구   커피숍  2014     NaN      NaN
# 107428  이디야  금천구   커피숍  2013     NaN      NaN
# 107818  이디야  강남구   커피숍  2015     NaN      NaN
# 108307  이디야  강남구   커피숍  2021     NaN      NaN
#
#                                         지번주소          경도         위도
# 42                    서울특별시 서초구 양재동 273-2 1층  126.988638  37.564465
# 147             서울특별시 송파구 문정동 150번지 올림픽훼밀리타운  126.971671  37.536150
# 350                    서울특별시 중구 신당동 373-70번지  127.027750  37.586012
# 399               서울특별시 송파구 문정동 640번지 케이디유타워  126.964918  37.581745
# 472                   서울특별시 중구 을지로6가 18-37번지  126.988101  37.569935
# ...                                      ...         ...        ...
# 107004                  서울특별시 관악구 신림동 408-40  127.033482  37.577416
# 107369               서울특별시 구로구 개봉동 403-50 2층  126.918742  37.462851
# 107428               서울특별시 구로구 개봉동 358-20 1층  127.003621  37.504364
# 107818  서울특별시 강남구 논현동 98-12 청호불교문화원 나동1층107호  126.912615  37.581202
# 108307                 서울특별시 동대문구 장안동 408-13  126.935884  37.556157
#
# [613 rows x 9 columns]

# %%
이디야.지역구.value_counts().sort_values(ascending=False)[:10]
# Out:
# 강남구     46
# 마포구     35
# 강서구     33
# 영등포구    32
# 송파구     31
# 노원구     31
# 양천구     29
# 관악구     29
# 강동구     26
# 금천구     26
# Name: 지역구, dtype: int64

# %%
# ! pip install pyproj

# ! pip install Proj

# ! pip install transform

# %%
from pyproj import Proj, transform

xycoord = sf.iloc[:, [24, 25]]
xycoord.head()


# Projection 정의
# 중부원점(Bessel): 서울 등 중부지역 EPSG:5174

proj_1 = Proj(init='epsg:5174')


# WGS84 경위도: GPS가 사용하는 좌표계 EPSG:4326
proj_2 = Proj(init='epsg:4326')


latlng = []
for i in range(len(강남스벅)):
    x_, y_ = transform(proj_1, proj_2, 강남스벅.iloc[i, 9], 강남스벅.iloc[i, 10])
    latlng.append((y_, x_))
    
fig = gmaps.figure(layout=mysize, center=seoul, zoom_level=12)

markers = gmaps.marker_layer(latlng)

fig.add_layer(markers)

embed_minimal_html('maps/starbucks2.html', views=[fig])
