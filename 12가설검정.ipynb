# %% [markdown]
# ## 추정
# * 보통 어떤 집단(모집단)의 특징을 알고싶다 -> 전수조사
# * 현실에서는 시간/비용상의 문제 때문에 모든 구성원 대상 조사는
#     + -> 표본 이용(일부 조사)
# * 알고자 하는 모집단의 특징을 숫자로 표현
#     + -> 모수(평균, 분산, 비율, 표준편차)
#     + 표본으로 뽑은 데이터 - 통계량, 추정치
# * **표본의 통계량으로 "'모수'가 이럴 것이다" 라고 추리** -> 추정

# %% [markdown]
# ## 한국 성인 남자의 평균 키 파악
# + **모집단** : 한국 성인 남자
# + **모수** : 평균
#     - 한국 성인남자 모두를 조사할 수 있으니 표본(남자 1000명)을 선정해서 평균을 구함
#     - 표본의 평균으로 모집단의 평균을 추리함
# + 추정은 일부 데이터로 전체를 추리하기 때문에 100% 정답은 아님, 일부 오차는 존재

# %% [markdown]
# ## 추정의 종류
# + 추정에는 점추정, 구간 추정이 있다.
# + 점추정
#     - 추정치를 하나의 값(점)으로 표현
#     - 성인 남자 평균 키 = 172.38cm(통계량)
#     - 그런데, 진짜 한국 남서의 평균키가 172cm일까?
#     - 당연히 그럴 확률은 희박 -> 표본수 작음, 오차 존재
#     - 따라서, 특성상 점추정은 신뢰하기 어려운
#     - 서울 지역내 하이마트에 UHD TV를 구매한 고객의 평균 나이
#     - 경주를 방문한 관광객들의 평균 지출액 추정
#
#
# + 구간 추정
#     - 추정치를 일정 구간으로 설정
#     - 즉, 신뢰도(신뢰수준)를 제시하면서 상한값과 하한값으로 추정
#     - 성인 남자 평균 키 - 172.38cm(통계량) -> 167~ 177(+-5)
#     - 이렇게 하면, 이 구간에 모수가 포함될 확률이 높아짐
#     - 추정치의 신뢰도를 높이고, 점추정치의 한계를 극복하기 위해
#     - 서울 지역 IT노동자의 연간 평균 급여가 200만원 이다 (점추정)
#     - 서울 지역 IT노동자의 연간 평균 급여가 180 ~ 220만원 사이에 있을 가능성 85% 이다
#     - (구간추정 - 어느 정도 신뢰도 보장)

# %% [markdown]
# ## 신뢰 구간
# + 점추정은 특성상 신뢰도가 떨어짐 -> 구간추정으로 보완
# + 그러면, 구간추정시 어느정도까지 구간을 설정해야 할까?
# + 성인 남자 평균 키에 대한 구간추정을 150~190으로 잡으면 >
# + 구간 설정이 짧을수록 좋을까? -> 너무 짧아도 문제
# + 너무 넓지도, 짧지않게 나름의 기준에 따라 신뢰가능한 구간을 설정
# + 주어진 확률로 모집단의 모수가 존재할 것으로 예상되는 값의 범위
# + 이때, 주어진 확률은 '신뢰수준' 이라 함
#     - 신뢰수준 = 표본으로부터 계산한 결과ㅏ에 대해 확실성 정도를 표현하는 것으로,
#     - 추정값으로 모수를 맞출 확률을 의미
#     - 90% ~ 99.9% 정도로 표현

# %% [markdown]
# ## 표본 추출방법
# + 표본 조사 : 수강생 5000명 대상 사용중인 핸드폰 선호도 조사를 위해 30명 선정
#     - 모집단 : 수강생 5000명
#     - 표본 : 수강생 30명
# + 단순 랜덤 : Simple Random Sampling
#     - 모집단 개체에 번호표 부여 후 30명 추출
#     - 추출틀 이용
# + 계통 추출 : 기본적으로 SRS와 유사
#     - 단, '개체수/표본수'로 계산되는 k값을 알아냄
#     - 1~n의 숫자중 하나를 선택하고 그 숫자에 k를 더해서 개체들을 선택
#     - ex) k : 3000/30 -> 100
#     - 임의의 숫자 뽑음( 1~3000): 25
#     - 25, 125, 225, 325, ..., 2925
# + 층화 추출 : 모집단을 몇개의 계층(고유특성)으로 나누어 표본 추출
#     - ex) 모집단 : 3000명 -> 남/여 수 파악
#     - 각 계층별로 번호 부여
#     - 계층별 비율 계산 : 남여 비율 = 7:3
#     - 따라서, 남자는 21명, 여자는 9명을 SRS로 추출
# + 군집 추출 : 모집단을 몇개의 군집(가변특성)으로 나누어 표본 추출
#     - ex) 모집단을 학력수준/ 거주지역으로 나눔
#     - 각 군집별로 번호 부여(고졸, 대졸, 대학원졸/ 서울/경기/부산)
#     - 임의의 그룹을 선택하고 번호표 부여 후 비율별로 SRS 추출

# %% [markdown]
# ## 표본추출 : sample
# + 복원추출
# + 비복원추출

# %%
x <- c(1:10)
# 10개의 모집단에서 1개의 표본 추출 (비복원)
sample(x,1)
# Out:
# [1] 1

# %%
# 10개의 모집단에서 5개의 표본 추출
sample(x,5)
# Out:
# [1] 10  9  4  3  6

# %%
sample(x, 5, replace=T) # 복원 추출
# Out:
# [1] 2 7 9 3 3

# %%
# 가중치를 부여한 표본 추출
# 가중치 = 1:1, 2:2, 3:3, ... 10:10
sample(x,5,prob=1:10)
# Out:
# [1]  6 10  8  4  7

# %% [markdown]
# ## 추론통계의 두 갈래
# * 모집단으로부터 표본을 추출해서 모집단의 특성을 나타내는 모수에 대한 여러 가지 정보를 얻음 : 추론통계
# * 통계적 추론 = 추정 + 가설검정

# %% [markdown]
# ## 가설 검정
# * 추론 통계학에서 중요하게 여기는 3가지
#     + 표본집단은 모집단을 대표할 수 있는가?
#     + 표본의 특성이 모집단을 잘 반영해야 함 -> 대표성을 지녀야 함
#     + 표본의 확률분포는 어떤가?
# * 어떤 분포이냐에 따라 추정을 위한 기법이 다름
# * 단, 표본의 수가 많아미녀 정규분포에 근사

# %% [markdown]
# ## 통계적 관점의 가설
# * 검정을 전제로 모집단의 모수에 대한 진술 또는 가정
#     - 하이마트에서 일하는 모든 종업원의 평균임금은 200만원이다 - 가설
#     - 이 가설이 옳은지 알아보기 위해서는 모든 영업점을 다 돌아봐야 함 = 사실상 불가능
#     - 일정 수의 표본을 추출해서 표본 통계량을 조사하고 결정규칙에 따라 가설을 채택하거나 기각할 수 있음
# * 표본통계량 조사 후:
#     - 표본 평균 100만원 -> 가설 기각
#     - 표본 평균 196만원 -> 가설채택? 오차 허용여부는?

# %% [markdown]
# ## 통계적 관점의 검정
# + 가설이 타당성 있는 진술인지 결정하기 위해 표본증거와

# %% [markdown]
# ## 가설검정의 6가지 절차
# 1. 귀무/대립가설 설정
#     - 검정하고자 하는 가설을 설정
#     - 귀무(null)가설 $H_0$
#         - 수치 증거를 검정하기 위한 목표로 만들어진 모집단 모수값에 대한 진술(가정)
#     - 대립(alternative)가설 $H_1$
#         - 표본 데이터 정보로 귀무가설이 거짓이라는 충분한 증거를 제시할 때 채택되는 진술
#     - 상업적 항공기의 평균수명은 25년인지 알고 싶다.
#         - 귀무가설 : 평균 수명은 25년이다 (=)
#         - 대립가설 : 평균 수명은 25년이 아니다/25년이상/25년이하
# 2. 유의수준 선정
#     - 귀무가설을 기각하게 되는 확률
#         - 일반적으로 소비자 관련 - 0.05
#         - 품질보증 관련 - 0.01
#         - 정치 여론 조사관련 - 0.10
#         - ex) 전자회로기판 PCB 생산업체에서 불량률이 6% 이하 일때
#         - 계약업체로 선적해서 납품한다는 품질보증계약 체결
#             - 귀무가설 H0 : 불량률 6% 이하 - 선적 O
#             - 대립가설 H1 : 불량률 6% 초과 - 선적 X
#         - 4000개의 회로판에서 표본 50개 추출
#             - 4개가 불량 -> 0.08 -> 8% -> 선적 X
#         - 그런데, 4개의 불량이 전체 4000개에서 유일 하다면?
#             - 불량률 0.1% -> 선적취소 잘못된 결정
#             - 귀무가설이 틀리지만 기각 못함 ( 제1종오류(알파$\alpha$))
#
# 3. 검정통계량 선택
# 4. 결정규칙 수립
# 5. 표본추출, 결론 도출
# 6. 결과 해석

# %% [markdown]
# ### 4. 결정규칙 수립 - 단측/양측 검정
# * 귀무가설이 기각될 특정 조건과 기각되지 않을 조건을 명시
# * 일반적으로 기각영역은 귀무가설이 발생할 가능성이 없도록 작게 설정
# * 단측검정 : one-side, 한쪽 꼬리 검정
#   - 방향성(크다/작다)이 대립가설에 포함되는 경우 시행하는 검정 우측(오른쪽) 단측검정
#   - 농심의 '오징어다리' 스낵의 포장중량이 500g미만인지 검정한다고 가정
#   - 귀무가설 : 포장중량이 500g미만
#   - 대립가설 : 포장중량이 500g이상
#   - 유의수준 0.05일때 귀무가설이 기각될 영역(기각역)은 임계값 1.645 기준 오른쪽 영역
#      + 임계값 : 귀무가설을 채택하거나 기각할 영역 사이의 분기점   좌측(왼쪽) 단측검정
#   - 현대 자동차에 장착되는 타이어의 평균 수명이 50000km 이상인지 검정
#     + 귀무가설 : 평균 수명이 50000km 이상
#     + 대립가설 : 평균 수명이 50000km 미만
#     + 유의수준 0.05일때 귀무가설이 기각될 영역(기각역)은
#       임계값 -1.645 기준 왼쪽 영역
# * 양측검정 - two sided, 양쪽 꼬리 검정
#   + 방향성(크다/작다)이 대립가설에 포함되지 않는 경우
#     시행하는 검정
#   + 회계사의 연평균 수입은 5500만원인가?
#     - 귀무가설 : 연평균 수입은 5500만원 이다
#     - 대립가설 : 연평균 수입은 5500만원 아니다
#   + 유의수준 0.05일때 귀무가설이 기각된 영역은
#     임계값 -1.96(0.025)/1.96(0.025) 기준 양쪽 영역임

# %% [markdown]
# ### 5. 결론도출
# * 만약, 계산된 검정 통계량 z값이
#     기각역을 넘는 값이라면 (ex: 2.34) 귀무가설은 기각됨
# * 계산된 검정 통계량 z값이 기각역을 넘지 않는
#   값이라면 (ex: 0.71) 귀무가설은 채택됨
# * 하지만, 1종오류/2종오류가 발생할 수도 있음
# * 유의확률 p-value
#   + 귀무가설이 참이라고 가정할때 주어진 데이터가 관측될 확률
#   + 또는 극단적인 데이터가 관측될 확률을 의미
#   + 따라서, **'유의확률이 유의수준보다 작으면 귀무가설을 기각할 수 있음'** (중요!)

# %% [markdown]
# ### 6. 결과 해석
#
# * 통계를 이용해서 가설검정이 모든 분야의 가설을 다 판단하지 못함
# * 수학적 특성상 제약이 존재(표본의 편중)
# * 판단의 의사결정시 수학적 방법을 이용하는 것도 좋지만,
#   수학의 틀에서 벗어나 의사결정하는 것도 좋음
#   -  => 동물적 직감, 영감을 이용
#
# * 즉, 참/거짓이 존재하는 수학적 가설과는 달리
#   통계적 가설은 참/거짓의 유무보다는 확률만 존재함
# * 언제나 틀릴 가능성 내포
#
#
# * 회계사의 연평균 수입은 5500만원인가?
#   + 귀무가설 : 연평균 수입은 5500만원 이다
#   + 대립가설 : 연평균 수입은 5500만원 아니다
#   + 결론 : 연평균 수입은 5500만원 이다 (x)
#   + 연평균 수입이 5500만원일/아닐 확률이 다소 높다/낮다 (o)

# %%
# 다음 자료는 커피판매점에 방문하는 성인들의 키를 조사한 것
# 이것으로 성인의 평균키가 67.6인치(172cm)인지 알아보자
# 귀무가설 : 성인의 평균키가 67.6인치이다
# 대립가설 : 성인의 평균키가 67.인치가 아니다
# 검정방법 : 양측검정
# 단일표본 t검정 : t.test(표본, 평균, 검정방법)

data <- read.csv('coffee.csv')
head(data)
# Out:
#   user_id age  drinks_coffee height
# 1 4509    <21  False         64.53818
# 2 1864    >=21 True          65.82425
# 3 2060    <21  False         71.31985
# 4 7875    >=21 True          68.56940
# 5 6254    <21  True          64.02023
# 6 3742    <21  False         63.49178

# %%
t.test(data$height, mu=67.6) # 양측검정
# 임계값 : 양측검정이므로 1.96/-1.96
# t 검정값 : -1.96 < -0.043944 :귀무가설 채택 
# 유의확률 :  0.965(유의수준 0.05보다 크므로 귀무가설 채택)
# Out:
# 	One Sample t-test
#
# data:  data$height
# t = -0.043933, df = 2973, p-value = 0.965
# alternative hypothesis: true mean is not equal to 67.6
# 95 percent confidence interval:
#  67.48533 67.70964
# sample estimates:
# mean of x
#  67.59749

# %% [markdown]
# - 2010년 어느 지역 중학교 1학년 남학생의 몸무게를 전수조사하니 평균 63kg, 표준편차 8.0kg이 나왔다.
# - 2015년 15명의 남학생을 표본추출해서 몸무게를 재보니
# - 70.2, 54.9, 67.0, 60.5, 63.4, 61.9, 65.9, 71.8, 66.1, 72.6, 73.0, 68.7, 70.3, 66.2, 55.6 일때
# - 이 지역 남학생의 몸무게는 5년전에 비해 증가했는가?
#
# * 귀무가설 : 남학생의 몸무게 변화 없다 = 평균 63kg이다
# * 대립가설 : 남학생의 몸무게 변화 있다 = 평균 63kg 이상이다
# * 방향성이 있는 대립가설 >> 단측검정 (★)
# * 유의수준 : 0.05
# * 자유도 : 단일표본 검정시 n -1 -> 14
# * 임계값 : t-table에서 검정유형, 자유도 이용 -> 1.761 (★)

# %%
stud <- c(70.2, 54.9, 67.0, 60.5, 63.4, 61.9, 65.9, 71.8, 66.1, 72.6, 73.0, 68.7, 70.3, 66.2, 55.6)

# %%
t.test(stud, mu=63, alternative=c('greater'))
# Out:
# 	One Sample t-test
#
# data:  stud
# t = 1.9507, df = 14, p-value = 0.0357
# alternative hypothesis: true mean is greater than 63
# 95 percent confidence interval:
#  63.27896      Inf
# sample estimates:
# mean of x
#  65.87333

# %% [markdown]
# - 어떤 보험회사의 클레임 평균 처리비용이 60달러라 할때, 비용절감 정책을 도입한 효과를 알아보려 한다
# - 지난달 처리된 26건의 클레임을 표본으로 채택할때 유의수준 0.01에서 처리비용이 평균 60미만인지 검정하시요
# - 단, 유의수준 0.01의 임계값은 2.485/-2.485이다
#
# - 귀무가설 : 처리비용이 평균 60 이다
# - 대립가설 : 처리비용이 평균 60 미만이다 - 단측
# - 유의수준 : 0.01
# - 임계값 : -2.485
# - -1.8165, pvalue:0.04065

# %%
# 45, 49, 62, 40, 43, 61, 48, 53, 67, 63, 78, 64, 76, 48, 54, 51, 56, 63, 69, 58, 51, 58, 59, 56, 57, 38
claims <- c(45, 49, 62, 40, 43, 61, 48, 53, 67, 63, 78, 64, 76, 48, 54, 51, 56, 63, 69, 58, 51, 58, 59, 56, 57, 38)

# %%
t.test(claims, mu=60, alternative=c('less'))
# Out:
# 	One Sample t-test
#
# data:  claims
# t = -1.8165, df = 25, p-value = 0.04065
# alternative hypothesis: true mean is less than 60
# 95 percent confidence interval:
#      -Inf 59.78662
# sample estimates:
# mean of x
#  56.42308

# %% [markdown]
# # 표본의 정규성
# * 정규성 검정은 표본집단의 분포상태를 확인해서
# * 모집단의 확률분포가 정규분포곡선을 따르는지 검정하는 것을 의미

# %% [markdown]
# # 정규성 확인 방법
# * 히스토그램이용 : 시각적으로 확인 (종모양 여부)
# * 분위수 그래프 : QQ 도표 (분위수/분위수 그래프)
# * shapiro-wilk 함수 이용 : shapiro-test

# %%
# 처리된 26건의 클레임을 표본의 정규성을 확인
hist(claims, probability =T )
lines(density(claims), col='red')
# Out:
# Plot with title “Histogram of claims”

# %%
# qq 도표
qqnorm(claims)
qqline(claims, col='red')
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
# shapiro-wilk 테스트 (유의 수준 0.05)
# 귀무가설 : 표본은 정규성을 따른다
# 대립가설 : 표본은 정규성을 따르지 않는다.
# p-value를 보고 유의수준은 별다른 언급이 없으면 0.05
# -> 0.9472 (귀무가설 채택 - 정규성을 따름)
shapiro.test(claims)
# Out:
# 	Shapiro-Wilk normality test
#
# data:  claims
# W = 0.98413, p-value = 0.9472

# %% [markdown]
# - 건장한 남성이 하루에 소비하는 물의 양은 평균 1.4리터인 정규분포를 따른다
# - 건강 캠페인으로 하루 최소 2리터를 마실것을 권고하였다.
# - 10명의 성인 남성을 뽑아서 조사해보니 1.5, 1.6, 1.5, 1.4, 1.9, 1.4, 1.3, 1.9, 1.8, 1.7 일때
# - 유의수준 0.01에서 물 소비량은 증가했다고 볼 수 있나?
#
# - 귀무가설 : 물 소비량은 증가하지 않았다 = 변화가 없다
# - 대립가설 : 물 소비량은 증가 했다.
# - 유의수준 : 0.01
# - 임계값 : 2.821

# %%
water = c(1.5, 1.6, 1.5, 1.4, 1.9, 1.4, 1.3, 1.9, 1.8, 1.7)

# %%
# 정규성 확인
hist(water, probability =T)
lines(density(water), col='red')
# Out:
# Plot with title “Histogram of water”

# %%
qqnorm(water)
qqline(water, col='red')
# Out:
# Plot with title “Normal Q-Q Plot”

# %%
shapiro.test(water) # 낮은 확률로 정규성 분포
# Out:
# 	Shapiro-Wilk normality test
#
# data:  water
# W = 0.92418, p-value = 0.3931

# %%
# 단일 표본 가설 검정
t.test(water, mu=1.4, alternative=c('greater'))
# Out:
# 	One Sample t-test
#
# data:  water
# t = 2.9277, df = 9, p-value = 0.00841
# alternative hypothesis: true mean is greater than 1.4
# 95 percent confidence interval:
#  1.474775      Inf
# sample estimates:
# mean of x
#       1.6

# %% [markdown]
# ## 두 표본 가설검정
# * 단일표본의 비교문제는 하나의 모집단에서 추출된 하나의 표본에 대해 검정
# * 그에 비해 두 표본 비교문제는 독립적(서로 관련없음)인 두 모집단으로 부터 각각 추출된 표본의 경우와
# * 동일한 모집단으로부터 추출된 두 표본의 경우로 나누어 검정을 실시함
#     - 남자와 여자간의 소득 차이 비교(독립표본),
#     - 과외를 받기 전과 후의 성적 차이 비교 (짝 표본)
# * 보통 2개의 집단간의 차이가 의미 있는지 확인
# * 일상에서는 단일 표본문제보다 더 많이 사용됨

# %% [markdown]
# ## 정규성 검정
# - 데이터의 분포가 정규분포를 따르는지 알아보는 것을 의미
# - 통계의 다양한 검정법은 데이터의 정규분포를 가정하고 수행됨
# - 데이터가 충분히 크다면(보통 30개 이상) 중심극한정리를 적용할 수 있음
# - 하지만, 그 이하일 경우 별도의 정규성 검정이 필요할 수 있음
# - 독립표본을 이용해서 가설검정을 실시하기 위해서는
# - 반드시 **정규성**, **등분산성**이 만족되어야 함

# %%
# ex) 독립표본 x, y 에 대해 정규성을 확인하시오
x <- c(175,168,168,190,156,181,182,175,174,179)
y <- c(185,169,173,173,188,186,175,174,179,180)

# %%
hist(x, probability=T)
lines(density(x), col='red')
hist(y)
# Out:
# Plot with title “Histogram of x”
# Plot with title “Histogram of y”
